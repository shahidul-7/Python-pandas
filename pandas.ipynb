# %%
import os
os.listdir("supermarkets")
# Out:
# ['supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

df1 = pandas.read_csv("supermarkets/supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets/supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel("supermarkets/supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets/data.txt", header=None)
df5.columns = ["ID", "Address", "City", "State", "Country", "Nae", "Number of Emplyees"]
df5
# Out:
#    ID          Address           City             State Country          Nae  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Number of Emplyees
# 0                   8
# 1                  15
# 2                  25
# 3                  10
# 4                  12
# 5                  20

# %%
df5.set_index("ID") #set any colum as index!
# Out:
#             Address           City             State Country          Nae  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Number of Emplyees
# ID
# 1                    8
# 2                   15
# 3                   25
# 4                   10
# 5                   12
# 6                   20

# %%
df5.loc["1":"4", "City":"Country"] #Slice by Lable
# Out:
#             City             State Country
# 1  San Francisco          CA 94119     USA
# 2  San Francisco  California 94114     USA
# 3  San Francisco          CA 94114     USA
# 4  San Francisco        California     USA

# %%
df5.iloc[1:4, 2:5] #Slice by index
# Out:
#             City             State Country
# 1  San Francisco          CA 94119     USA
# 2  San Francisco  California 94114     USA
# 3  San Francisco          CA 94114     USA

# %%
df5.iloc[:,0:5]
# Out:
#    ID          Address           City             State Country
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA

# %%
df5
# Out:
#    ID          Address           City             State Country          Nae  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Number of Emplyees
# 0                   8
# 1                  15
# 2                  25
# 3                  10
# 4                  12
# 5                  20

# %%
df6 = pandas.read_json("supermarkets/supermarkets.json")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.drop("City", axis=1)
# Out:
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df6.drop(df6.index[4:6], axis=0) #Delete Colums
# Out:
#    ID         Address           City             State Country         Name  \
# 0   1    3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2  735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3     332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4    3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10

# %%
df6.drop(df6.columns[0:4], axis=1)
# Out:
#   Country         Name  Employees
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20

# %%
df6["Area"] = ["Rajshahi", "Magura", "Jahlukathi", "Jamalpur", "Foridpur", "Barguna"] #Adding New Column
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees        Area
# 0          8    Rajshahi
# 1         15      Magura
# 2         25  Jahlukathi
# 3         10    Jamalpur
# 4         12    Foridpur
# 5         20     Barguna

# %%
df6["Area"] = df6["Country"] + ", " + "Replace with Area" #Replaced Colum with another colum and text
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                    Area
# 0          8  USA, Replace with Area
# 1         15  USA, Replace with Area
# 2         25  USA, Replace with Area
# 3         10  USA, Replace with Area
# 4         12  USA, Replace with Area
# 5         20  USA, Replace with Area

# %%
df_t = df6.T
df_t
# Out:
#                                  0                        1  \
# ID                               1                        2
# Address    San Francisco, CA 94114  San Francisco, CA 94119
# City                 San Francisco            San Francisco
# State                     CA 94114                 CA 94119
# Country                        USA                      USA
# Name                       Madeira              Bready Shop
# Employees                        8                       15
# Area        USA, Replace with Area   USA, Replace with Area
#
#                                          2                        3  \
# ID                                       3                        4
# Address    San Francisco, California 94114  San Francisco, CA 94114
# City                         San Francisco            San Francisco
# State                     California 94114                 CA 94114
# Country                                USA                      USA
# ...

# %%
df_t["New Colum"] = ["My ID", "My ID", "My ID", "My ID", "My ID", "My ID", "My ID", "My IT" ]
df_t
# Out:
#                                  0                        1  \
# ID                               1                        2
# Address    San Francisco, CA 94114  San Francisco, CA 94119
# City                 San Francisco            San Francisco
# State                     CA 94114                 CA 94119
# Country                        USA                      USA
# Name                       Madeira              Bready Shop
# Employees                        8                       15
# Area        USA, Replace with Area   USA, Replace with Area
#
#                                          2                        3  \
# ID                                       3                        4
# Address    San Francisco, California 94114  San Francisco, CA 94114
# City                         San Francisco            San Francisco
# State                     California 94114                 CA 94114
# Country                                USA                      USA
# ...

# %%
df_7 = df_t.T
df_t
# Out:
#               ID                          Address           City  \
# 0              1          San Francisco, CA 94114  San Francisco
# 1              2          San Francisco, CA 94119  San Francisco
# 2              3  San Francisco, California 94114  San Francisco
# 3              4          San Francisco, CA 94114  San Francisco
# 4              5        San Francisco, California  San Francisco
# 5              6          San Francisco, CA 94114  San Francisco
# New Colum  My ID                            My ID          My ID
#
#                       State Country         Name Employees  \
# 0                  CA 94114     USA      Madeira         8
# 1                  CA 94119     USA  Bready Shop        15
# 2          California 94114     USA  Super River        25
# 3                  CA 94114     USA   Ben's Shop        10
# 4                California     USA      Sanchez        12
# 5                  CA 94114     USA   Richvalley        20
# ...
